# %%
using PyPlot

include("../src/histogram_merging.jl")
# Out:
# fit_histogram_merging (generic function with 1 method)

# %%
k = 20
bin_values = rand(1:10, k);

# %%
n = 1000
y, ystar = generate_equal_size_histogram_data(bin_values, n, 1)
x = collect(linspace(0.0, 1.0, n));

# %%
plot(y)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3205eca90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x320a05810>

# %%
yhat_partition = fit_histogram_merging(y, 1.0, 20, 10, initial_merging_size = 1)
# Out:
# 20-element Array{HistogramPiece,1}:
#  HistogramPiece(1,50,8.99192)
#  HistogramPiece(51,78,1.88669)
#  HistogramPiece(79,98,2.21438)
#  HistogramPiece(99,102,3.79974)
#  HistogramPiece(103,150,2.91051)
#  HistogramPiece(151,200,8.09077)
#  HistogramPiece(201,204,3.22423)
#  HistogramPiece(205,250,3.05204)
#  HistogramPiece(251,300,8.07867)
#  HistogramPiece(301,350,1.72389)
#  HistogramPiece(351,400,6.31674)
#  HistogramPiece(401,450,1.91983)
#  HistogramPiece(451,506,6.95833)
#  HistogramPiece(507,554,5.14026)
#  HistogramPiece(555,600,5.99253)
#  HistogramPiece(601,698,3.98771)
#  HistogramPiece(699,754,6.77658)
#  HistogramPiece(755,800,6.06664)
#  HistogramPiece(801,850,10.2559)
#  HistogramPiece(851,1000,2.5365)

# %%
yhat = partition_to_vector(yhat_partition)
# Out:
# 1000-element Array{Float64,1}:
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  8.99192
#  ⋮
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365
#  2.5365

# %%
plot(yhat)
plot(ystar)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320a2f750>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x320fb7990>

# %%
length(yhat)
# Out:
# 1000

# %%
mse(yhat, ystar)
# Out:
# 0.10623619233725683
