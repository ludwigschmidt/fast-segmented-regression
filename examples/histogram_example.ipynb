# %%
using PyPlot

include("../src/histogram_merging.jl")
# Out:
# fit_histogram_merging (generic function with 1 method)

# %%
k = 20
bin_values = rand(1:10, k);

# %%
n = 1000
y, ystar = generate_equal_size_histogram_data(bin_values, n, 1)
x = collect(range(0.0, 1.0, n));

# %%
plot(y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x1755e7580>

# %%
yhat_partition = fit_histogram_merging(y, 1.0, 20, 10, initial_merging_size = 1)
# Out:
# 20-element Vector{HistogramPiece}:
#  HistogramPiece(1, 46, 2.271016345894986)
#  HistogramPiece(47, 54, 3.664756905019706)
#  HistogramPiece(55, 100, 4.844568084433753)
#  HistogramPiece(101, 136, 8.227936321924602)
#  HistogramPiece(137, 168, 6.895829711364123)
#  HistogramPiece(169, 204, 5.5561155946001115)
#  HistogramPiece(205, 236, 2.992528741747312)
#  HistogramPiece(237, 250, 2.698067255228775)
#  HistogramPiece(251, 269, 8.426525572133073)
#  HistogramPiece(270, 298, 8.222504609953434)
#  HistogramPiece(299, 352, 6.953524833608087)
#  HistogramPiece(353, 450, 8.999021182920227)
#  HistogramPiece(451, 500, 2.0114501377020013)
#  HistogramPiece(501, 600, 7.372473707775911)
#  HistogramPiece(601, 662, 2.6870883727082298)
#  HistogramPiece(663, 700, 0.7395044274876721)
#  HistogramPiece(701, 794, 2.006681305724354)
#  HistogramPiece(795, 900, 4.401381826785947)
#  HistogramPiece(901, 950, 9.915891156530938)
#  HistogramPiece(951, 1000, 4.096036619713854)

# %%
yhat = partition_to_vector(yhat_partition)
# Out:
# 1000-element Vector{Float64}:
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  2.271016345894986
#  ⋮
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854
#  4.096036619713854

# %%
plot(yhat)
plot(ystar)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x175a7e470>

# %%
length(yhat)
# Out:
# 1000

# %%
mse(yhat, ystar)
# Out:
# 0.23502998069850278
